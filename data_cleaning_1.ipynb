# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_csv("credit_customers.csv")

# %%
df.head(10)
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0       6.0  critical/other existing credit
# 1        0<=X<200      48.0                   existing paid
# 2     no checking      12.0  critical/other existing credit
# 3              <0      42.0                   existing paid
# 4              <0      24.0              delayed previously
# 5     no checking      36.0                   existing paid
# 6     no checking      24.0                   existing paid
# 7        0<=X<200      36.0                   existing paid
# 8     no checking      12.0                   existing paid
# 9        0<=X<200      30.0  critical/other existing credit
#
#                purpose  credit_amount    savings_status  employment  \
# 0             radio/tv         1169.0  no known savings         >=7
# 1             radio/tv         5951.0              <100      1<=X<4
# 2            education         2096.0              <100      4<=X<7
# ...

# %%
df.isnull().sum()
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
df.drop(columns = ['checking_status', 'duration', 'credit_history' , 'purpose', 'other_parties', 'residence_since', 'property_magnitude', 'other_payment_plans', 'savings_status', 'num_dependents', 'housing', 'foreign_worker'], inplace=True, errors='ignore')

# %%
df.columns
# Out:
# Index(['credit_amount', 'employment', 'installment_commitment',
#        'personal_status', 'age', 'existing_credits', 'job', 'own_telephone',
#        'class'],
#       dtype='object')

# %%
df_new_columns = []
for i in df.columns:
    df_new_columns.append(i.capitalize())

# %%
df.columns = df_new_columns

# %%
df
# Out:
#      Credit_amount  Employment  Installment_commitment     Personal_status  \
# 0           1169.0         >=7                     4.0         male single
# 1           5951.0      1<=X<4                     2.0  female div/dep/mar
# 2           2096.0      4<=X<7                     2.0         male single
# 3           7882.0      4<=X<7                     2.0         male single
# 4           4870.0      1<=X<4                     3.0         male single
# ..             ...         ...                     ...                 ...
# 995         1736.0      4<=X<7                     3.0  female div/dep/mar
# 996         3857.0      1<=X<4                     4.0        male div/sep
# 997          804.0         >=7                     4.0         male single
# 998         1845.0      1<=X<4                     4.0         male single
# 999         4576.0  unemployed                     3.0         male single
#
# ...

# %%
# for data cleaning, first we drop reduntant columns meaning which will not give us any benefit

# %%
#then we just capitalize it and now we drop duplicates and naN values if we find any

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True) #for dropping duplicate values

# %%
df
# Out:
#      Credit_amount  Employment  Installment_commitment     Personal_status  \
# 0           1169.0         >=7                     4.0         male single
# 1           5951.0      1<=X<4                     2.0  female div/dep/mar
# 2           2096.0      4<=X<7                     2.0         male single
# 3           7882.0      4<=X<7                     2.0         male single
# 4           4870.0      1<=X<4                     3.0         male single
# ..             ...         ...                     ...                 ...
# 995         1736.0      4<=X<7                     3.0  female div/dep/mar
# 996         3857.0      1<=X<4                     4.0        male div/sep
# 997          804.0         >=7                     4.0         male single
# 998         1845.0      1<=X<4                     4.0         male single
# 999         4576.0  unemployed                     3.0         male single
#
# ...

# %%
df.isna().sum()
# Out:
# Credit_amount             0
# Employment                0
# Installment_commitment    0
# Personal_status           0
# Age                       0
# Existing_credits          0
# Job                       0
# Own_telephone             0
# Class                     0
# dtype: int64

# %%
df.dropna(inplace=True) #to drop naN values

# %%
df
# Out:
#      Credit_amount  Employment  Installment_commitment     Personal_status  \
# 0           1169.0         >=7                     4.0         male single
# 1           5951.0      1<=X<4                     2.0  female div/dep/mar
# 2           2096.0      4<=X<7                     2.0         male single
# 3           7882.0      4<=X<7                     2.0         male single
# 4           4870.0      1<=X<4                     3.0         male single
# ..             ...         ...                     ...                 ...
# 995         1736.0      4<=X<7                     3.0  female div/dep/mar
# 996         3857.0      1<=X<4                     4.0        male div/sep
# 997          804.0         >=7                     4.0         male single
# 998         1845.0      1<=X<4                     4.0         male single
# 999         4576.0  unemployed                     3.0         male single
#
# ...

# %%
df['Class'] = df['Class'].apply(lambda x:1 if x == 'good' else 0)

# %%
df
# Out:
#      Credit_amount  Employment  Installment_commitment     Personal_status  \
# 0           1169.0         >=7                     4.0         male single
# 1           5951.0      1<=X<4                     2.0  female div/dep/mar
# 2           2096.0      4<=X<7                     2.0         male single
# 3           7882.0      4<=X<7                     2.0         male single
# 4           4870.0      1<=X<4                     3.0         male single
# ..             ...         ...                     ...                 ...
# 995         1736.0      4<=X<7                     3.0  female div/dep/mar
# 996         3857.0      1<=X<4                     4.0        male div/sep
# 997          804.0         >=7                     4.0         male single
# 998         1845.0      1<=X<4                     4.0         male single
# 999         4576.0  unemployed                     3.0         male single
#
# ...

# %%
df['Own_telephone'].nunique()
# Out:
# 2

# %%
df['Own_telephone'].unique()
# Out:
# array(['yes', 'none'], dtype=object)

# %%
df['Own_telephone'] = df['Own_telephone'].apply(lambda x:1 if x == 'yes' else 0)

# %%
df
# Out:
#      Credit_amount  Employment  Installment_commitment     Personal_status  \
# 0           1169.0         >=7                     4.0         male single
# 1           5951.0      1<=X<4                     2.0  female div/dep/mar
# 2           2096.0      4<=X<7                     2.0         male single
# 3           7882.0      4<=X<7                     2.0         male single
# 4           4870.0      1<=X<4                     3.0         male single
# ..             ...         ...                     ...                 ...
# 995         1736.0      4<=X<7                     3.0  female div/dep/mar
# 996         3857.0      1<=X<4                     4.0        male div/sep
# 997          804.0         >=7                     4.0         male single
# 998         1845.0      1<=X<4                     4.0         male single
# 999         4576.0  unemployed                     3.0         male single
#
# ...

# %%
df['Existing_credits'] = df['Existing_credits'].astype('int')

# %%
df
# Out:
#      Credit_amount  Employment  Installment_commitment     Personal_status  \
# 0           1169.0         >=7                     4.0         male single
# 1           5951.0      1<=X<4                     2.0  female div/dep/mar
# 2           2096.0      4<=X<7                     2.0         male single
# 3           7882.0      4<=X<7                     2.0         male single
# 4           4870.0      1<=X<4                     3.0         male single
# ..             ...         ...                     ...                 ...
# 995         1736.0      4<=X<7                     3.0  female div/dep/mar
# 996         3857.0      1<=X<4                     4.0        male div/sep
# 997          804.0         >=7                     4.0         male single
# 998         1845.0      1<=X<4                     4.0         male single
# 999         4576.0  unemployed                     3.0         male single
#
# ...

# %%
type(df['Existing_credits'][0])
# Out:
# numpy.int64

# %%
df.to_csv('cleaned_credit_customer.csv', index=False)
